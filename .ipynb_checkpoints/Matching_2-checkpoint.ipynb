# %%
import pandas as pd
from pyjarowinkler import distance

# %% [markdown]
# Матчінг після фільтрації по мовам, мерджингу з фільтруванням по спільним словам/кодам

# %%
df = pd.read_csv('result_data.csv')

# %%
df.head()
# Out:
#       TIN                    FULL_NAME                    json_id  \
# 0  376372           барський спиртовий  NK-77BJ8UbfBduQzXWhrx2KvK
# 1  376372           барський спиртовий  NK-CadUMN6nMs9t56nuQE7YCk
# 2  376372  барський спиртовий комбінат  NK-P2q7vwBofBCY2VP5MoTcmJ
# 3  376372  барський спиртовий комбінат  NK-R58MnnJo2WdbGCNxnMwsGj
# 4  376372  барський спиртовий комбінат  NK-TrLccKcfToTWKaN7gHmtpg
#
#                                                 name           ogrnCode  \
# 0             федеральне  унітарне  гірничо-хімічний  ['1022401404871']
# 1            федеральне  унітарне   електрохімприлад  ['1026601766950']
# 2  так зване   зв'язку  унітарне  донецької народ...            ['N/A']
# 3     федеральне  унітарне  науково-виробниче  гамма  ['1027739443830']
# 4  федеральне  унітарне  дослідний завод вега доч...  ['1024000537571']
#
#           innCode                                          sanctions  \
# 0  ['2452000401']  [{'id': 'ua-nazk-7767172472f1f2a643f5ac13906b6...
# 1  ['6630002336']  [{'id': 'ua-nazk-8a07b1dff5a6e05762b22c4639dda...
# 2             NaN  [{'id': 'ua-nazk-66fe74ac5b23e466f77f2fae6021e...
# 3  ['7728044373']  [{'id': 'ca-sema-2f16a2d0917622c6608b6aba40439...
# 4  ['4003005290']  [{'id': 'ch-seco-9e37b7b8970ee6c99eac36993f8b2...
#
#    related_to  same_code  same_name            redused_full_name  \
# 0         NaN      False       True           барський спиртовий
# 1         NaN      False       True           барський спиртовий
# 2         NaN      False       True  барський спиртовий комбінат
# 3         NaN      False       True  барський спиртовий комбінат
# 4         NaN      False       True  барський спиртовий комбінат
#
#                                    redused_json_name
# 0             федеральне  унітарне  гірничо-хімічний
# 1            федеральне  унітарне   електрохімприлад
# 2  так зване   зв'язку  унітарне  донецької народ...
# 3     федеральне  унітарне  науково-виробниче  гамма
# 4  федеральне  унітарне  дослідний завод вега доч...

# %% [markdown]
# Перевіряю чи взагалі є однакові коди
# Для цього піднабору - жодного(((

# %%
df[['same_code', 'same_name']].value_counts()
# Out:
# same_code  same_name
# False      True         100001
# Name: count, dtype: int64

# %%
df[['FULL_NAME', 'name']].isna().any()
# Out:
# FULL_NAME    False
# name         False
# dtype: bool

# %%
df['FULL_NAME'] = df['FULL_NAME'].astype(str)
df['name'] = df['name'].astype(str)

# %% [markdown]
# Тест системи

# %%
df['distance'] = df.apply(lambda x : distance.get_jaro_distance(str(x.redused_full_name), str(x.redused_json_name)), axis = 1)

# %%
df.distance.describe()
# Out:
# count    100001.000000
# mean          0.690960
# std           0.132225
# min           0.000000
# 25%           0.680000
# 50%           0.720000
# 75%           0.750000
# max           0.920000
# Name: distance, dtype: float64

# %%
df.head()
# Out:
#       TIN                    FULL_NAME                    json_id  \
# 0  376372           барський спиртовий  NK-77BJ8UbfBduQzXWhrx2KvK
# 1  376372           барський спиртовий  NK-CadUMN6nMs9t56nuQE7YCk
# 2  376372  барський спиртовий комбінат  NK-P2q7vwBofBCY2VP5MoTcmJ
# 3  376372  барський спиртовий комбінат  NK-R58MnnJo2WdbGCNxnMwsGj
# 4  376372  барський спиртовий комбінат  NK-TrLccKcfToTWKaN7gHmtpg
#
#                                                 name           ogrnCode  \
# 0             федеральне  унітарне  гірничо-хімічний  ['1022401404871']
# 1            федеральне  унітарне   електрохімприлад  ['1026601766950']
# 2  так зване   зв'язку  унітарне  донецької народ...            ['N/A']
# 3     федеральне  унітарне  науково-виробниче  гамма  ['1027739443830']
# 4  федеральне  унітарне  дослідний завод вега доч...  ['1024000537571']
#
#           innCode                                          sanctions  \
# 0  ['2452000401']  [{'id': 'ua-nazk-7767172472f1f2a643f5ac13906b6...
# 1  ['6630002336']  [{'id': 'ua-nazk-8a07b1dff5a6e05762b22c4639dda...
# 2             NaN  [{'id': 'ua-nazk-66fe74ac5b23e466f77f2fae6021e...
# 3  ['7728044373']  [{'id': 'ca-sema-2f16a2d0917622c6608b6aba40439...
# 4  ['4003005290']  [{'id': 'ch-seco-9e37b7b8970ee6c99eac36993f8b2...
#
#    related_to  same_code  same_name            redused_full_name  \
# 0         NaN      False       True           барський спиртовий
# 1         NaN      False       True           барський спиртовий
# 2         NaN      False       True  барський спиртовий комбінат
# 3         NaN      False       True  барський спиртовий комбінат
# 4         NaN      False       True  барський спиртовий комбінат
#
#                                    redused_json_name  distance
# 0             федеральне  унітарне  гірничо-хімічний      0.39
# 1            федеральне  унітарне   електрохімприлад      0.38
# 2  так зване   зв'язку  унітарне  донецької народ...      0.45
# 3     федеральне  унітарне  науково-виробниче  гамма      0.49
# 4  федеральне  унітарне  дослідний завод вега доч...      0.40

# %%
df.sort_values(by = 'distance', ascending = False).head(5)
# Out:
#             TIN                      FULL_NAME                    json_id  \
# 21026   5466772  відповідальністю будматеріали  NK-2pSJdL4VFrnMFzYWmYYLCL
# 65521  13331945         відповідальністю одчий  NK-hsJwRQpMv7WUSMvzka4yD7
# 21368   5466772  відповідальністю будматеріали  NK-7nyTNZQ4zTBxNX3VZCGGcT
# 72600  31086753        вiдповiдальнiстю агат-а  NK-CEK2aTc9ryrCCwMPncfwSF
# 22173   5466772  відповідальністю будматеріали  NK-KMRDn27sSSaojSe4nREx5w
#
#                                name           ogrnCode         innCode  \
# 21026       відповідальністюдубрава  ['1024700555440']  ['4703056519']
# 65521         відповідальністюарако  ['1117847369122']  ['7817323763']
# 21368      відповідальністютрадиція  ['1037804026611']  ['7802160805']
# 72600        відповідальністюагат-а  ['1227800110856']  ['7841100180']
# 22173  відповідальніст негабаритика  ['1133116000270']  ['3116006409']
#
#                                                sanctions  related_to  \
# 21026  [{'id': 'ua-nazk-42284cb6c32fd9c128204b684ad79...         NaN
# 65521  [{'id': 'ua-nazk-1afe833ea06ed62adafa80e8f78be...         NaN
# 21368  [{'id': 'ua-nazk-fc323817ca97b8709d9ba97add935...         NaN
# 72600  [{'id': 'ua-nazk-4f4a8e01cb018adc888f0a372dbef...         NaN
# 22173  [{'id': 'ua-nazk-186909d91f55879cd8756cde29cf7...         NaN
#
#        same_code  same_name        redused_full_name redused_json_name  \
# 21026      False       True             будматеріали           дубрава
# 65521      False       True                    одчий             арако
# 21368      False       True             будматеріали          традиція
# 72600      False       True  вiдповiдальнiстю агат-а            агат-а
# 22173      False       True             будматеріали      негабаритика
#
#        distance
# 21026      0.92
# 65521      0.92
# 21368      0.91
# 72600      0.91
# 22173      0.91

# %% [markdown]
# Не втішний, надто багато шуму, в топі найкращої відстані, немає толком метчів(за винятком агат-а)

# %% [markdown]
# Вирішив почистити "відповідальністю", бо бачу, що з якихось причин вона збереглась в багатьох записах.
# Можливо через різні кодування/символи

# %%
df['redused_json_name'] = df['redused_json_name'].astype(str)
df['redused_full_name'] = df['redused_full_name'].astype(str)

# %%
df['redused_json_name'] = df['redused_json_name'].str.replace('відповідальністю', '')
df['redused_json_name'] = df['redused_json_name'].str.replace('відповідальніст', '')

df['redused_full_name'] = df['redused_full_name'].str.replace('відповідальністю', '')
df['redused_full_name'] = df['redused_full_name'].str.replace('відповідальніст', '')

# %%
def calc_dist(str1, str2):
    if(len(str1) == 0):
        str1 = 's'
    if(len(str2) == 0):
        str2 = 's'
    return distance.get_jaro_distance(str1, str2)

# %%
df['distance'] = df.apply(lambda x : calc_dist(str(x.redused_full_name), str(x.redused_json_name)), axis = 1)

# %%
df.sort_values(by = 'distance', ascending = False)
# Out:
#             TIN                                    FULL_NAME  \
# 6010   34244416                вiдповiдальнiстю пфаннер агро
# 23899   5466772                                 будматеріали
# 21501   5466772                   товариство    будматеріали
# 43833  33543380  обмеженою вiдповiдальнiстю правнича  справа
# 64326  13331945                             обмеженою  одчий
# ...         ...                                          ...
# 15170  42954704                вiдповiдальнiстю агро-ровиток
# 15172  42954704                вiдповiдальнiстю агро-ровиток
# 47039  33623240                   вiдповiдальнiстю флоріан-т
# 76238  33781896      вiдповiдальнiстю торговий дім інтеркорн
# 65840  13331945                                        одчий
#
#                          json_id  \
# 6010   NK-oUHjoxn7Zk6vRFwzrG7X7h
# 23899  NK-ndGcLhdEwuc66GU2dScrrM
# 21501  NK-9Zzvya86wceNdL3qrdsZuH
# 43833  NK-W5usohSWk2RNwsyup5JbRb
# 64326  NK-P3qArVxXnsSpFc9Furmfps
# ...                          ...
# 15170  NK-4akjxfj4WVbHDeNUhs4bAg
# 15172  NK-4dAFwiGv5fVPFNzVjWhfaW
# 47039  NK-ZSbg3MyadjHaDdAtpuNSWT
# 76238  NK-NAFYhnUkAkjmw33RzTy3k8
# 65840  NK-nxganH6MCPFbRobdEMYni9
#
#                                                     name           ogrnCode  \
# 6010                          відпоідальністю сохра груп      ['192363182']
# 23899                                          будсервис  ['1172375020234']
# 21501                             твариство    сампоерна       ['43732520']
# 43833  обмеженоювідповідальністю перша міжнароднабукм...  ['1087746968759']
# 64326     обмежувальною  суднохідне агентство транс-флот  ['1073703000975']
# ...                                                  ...                ...
# 15170                              відповідальністю агат  ['1027804189830']
# 15172                       відповідальністю ''1ss і к''  ['1027739885557']
# 47039                          відповідальністю атм груп  ['1085029001309']
# 76238                                відповідальністю тк  ['1187847101529']
# 65840                      науково-виробниче     окб тсп      ['190369982']
#
#               innCode                                          sanctions  \
# 6010              NaN  [{'id': 'be-fod-c75de2d844fc56a21340896f408653...
# 23899  ['2352053960']  [{'id': 'ua-nazk-d2766d46c8ef17bed8ff43ad9f018...
# 21501             NaN  [{'id': 'ua-nazk-7c3ec315440507a0c8112ef187cd0...
# 43833  ['7729607406']  [{'id': 'ua-nazk-84270d486066a3c2a4aad9d8e4e7e...
# 64326  ['3703039938']  [{'id': 'ua-nazk-7d0a51ff578de86769e506b67aa35...
# ...               ...                                                ...
# 15170  ['7804051110']  [{'id': 'ua-nazk-56b6ae821f3a0260edb03e6cb044a...
# 15172  ['7705012512']  [{'id': 'ua-nazk-264543cf36cca90da1e9713f1915d...
# 47039  ['5029111665']  [{'id': 'ua-nazk-2dfda32c19b48f0f10bf5f1a11f4a...
# 76238  ['7804618544']  [{'id': 'ua-nazk-0ba64615ccf4b94ed3fe5b57ac87b...
# 65840   ['190369982']  [{'id': 'au-dfat-70415af6a82d32f5b095130db3bfd...
#
#        related_to  same_code  same_name  \
# 6010          NaN      False       True
# 23899         NaN      False       True
# 21501         NaN      False       True
# 43833         NaN      False       True
# 64326         NaN      False       True
# ...           ...        ...        ...
# 15170         NaN      False       True
# 15172         NaN      False       True
# 47039         NaN      False       True
# 76238         NaN      False       True
# 65840         NaN      False       True
#
#                                  redused_full_name  \
# 6010                 вiдповiдальнiстю пфаннер агро
# 23899                                 будматеріали
# 21501                   товариство    будматеріали
# 43833  обмеженою вiдповiдальнiстю правнича  справа
# 64326                             обмеженою  одчий
# ...                                            ...
# 15170                вiдповiдальнiстю агро-ровиток
# 15172                вiдповiдальнiстю агро-ровиток
# 47039                   вiдповiдальнiстю флоріан-т
# 76238      вiдповiдальнiстю торговий дім інтеркорн
# 65840                                        одчий
#
#                                     redused_json_name  distance
# 6010                       відпоідальністю сохра груп      0.81
# 23899                                       будсервис      0.81
# 21501                          твариство    сампоерна      0.80
# 43833          обмеженою перша міжнароднабукмекерська      0.79
# 64326  обмежувальною  суднохідне агентство транс-флот      0.79
# ...                                               ...       ...
# 15170                                            агат      0.00
# 15172                                     ''100 і к''      0.00
# 47039                                        атм груп      0.00
# 76238                                              тк      0.00
# 65840                   науково-виробниче     окб тсп      0.00
#
# [100001 rows x 13 columns]

# %% [markdown]
# Результат все ще не втішний
#
# Більше того, чомусь "відповідальністю" толком не почистилось, що ще раз підштовхує до думки про формати символів чи стрічок, певні невідповідності у символах тощо
#
# Більше того є явні опечатки в даних(наприклад твариство, а не товариство)
